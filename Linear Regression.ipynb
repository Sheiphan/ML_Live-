# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('D:\Python\ML Live\Modular1\ML_Live-\data\Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df['total_spend']= df['TV'] + df['Radio'] + df['Newspaper']
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales  total_spend
# 0           1  230.1   37.8       69.2   22.1        337.1
# 1           2   44.5   39.3       45.1   10.4        128.9
# 2           3   17.2   45.9       69.3    9.3        132.4
# 3           4  151.5   41.3       58.5   18.5        251.3
# 4           5  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df, x='total_spend', y='Sales')
# Out:
# <AxesSubplot:xlabel='total_spend', ylabel='Sales'>

# %%
sns.regplot(data=df, x='total_spend', y='Sales', color='green')
# Out:
# <AxesSubplot:xlabel='total_spend', ylabel='Sales'>

# %%
x= df['total_spend']
y= df['Sales']

# %%
np.polyfit(x,y, deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
np.polyfit(x,y ,deg=3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
potential_spend = np.linspace(0,500,100)
potential_spend
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
# ...

# %%
#y=mx^2+bx+c
predicted_sales= (3.07615033e-07*(potential_spend)**3) + -1.89392449e-04*(potential_spend)**2 + 8.20886302e-02*(potential_spend) + 2.70495053e+00

predicted_sales
# Out:
# array([ 2.70495053,  3.11474825,  3.51512186,  3.90630911,  4.28854779,
#         4.66207567,  5.02713053,  5.38395013,  5.73277224,  6.07383466,
#         6.40737513,  6.73363145,  7.05284138,  7.3652427 ,  7.67107318,
#         7.97057059,  8.2639727 ,  8.5515173 ,  8.83344215,  9.10998503,
#         9.38138371,  9.64787596,  9.90969955, 10.16709227, 10.42029188,
#        10.66953616, 10.91506288, 11.15710981, 11.39591473, 11.63171541,
#        11.86474963, 12.09525515, 12.32346975, 12.54963121, 12.77397729,
#        12.99674578, 13.21817443, 13.43850104, 13.65796337, 13.87679919,
#        14.09524628, 14.31354241, 14.53192536, 14.75063289, 14.96990278,
#        15.18997281, 15.41108075, 15.63346437, 15.85736144, 16.08300974,
#        16.31064705, 16.54051112, 16.77283975, 17.0078707 , 17.24584174,
#        17.48699065, 17.73155521, 17.97977318, 18.23188233, 18.48812045,
#        18.74872531, 19.01393467, 19.28398632, 19.55911802, 19.83956755,
# ...

# %%
sns.scatterplot(x='total_spend', y='Sales', data=df)   #scatter
plt.plot(potential_spend, predicted_sales, color='green') #line

# %%
plt.plot(  [4,3.3,2,5.7,6] , color='green')

# %%
spend = 200
predicted_sales=(0.00000821901022*(spend)**2) + 4.53486875e-02*(spend) + 4.51143622
predicted_sales
# Out:
# 13.9099341288

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,3))   # subplot 1x3 multiple graphs. axes defines where which graph goes.

axes[1].plot(df['TV'], df['Sales'], 'o')
axes[1].set_ylabel('Sales')
axes[1].set_title('TV Spend')

axes[0].plot(df['Radio'], df['Sales'], 'o', color='green')
axes[0].set_ylabel('Sales')
axes[0].set_title('Radio Spend')

axes[2].plot(df['Newspaper'], df['Sales'], 'o')
axes[2].set_ylabel('Sales')
axes[2].set_title('newspaper Spend')
# Out:
# Text(0.5, 1.0, 'newspaper Spend')

# %%
sns.pairplot(df)

# %%
X=df.drop(['Sales','total_spend'],axis=1)
X
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
help(train_test_split)
# Out:
# Help on function train_test_split in module sklearn.model_selection._split:
#
# train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
#     Split arrays or matrices into random train and test subsets.
#
#     Quick utility that wraps input validation and
#     ``next(ShuffleSplit().split(X, y))`` and application to input data
#     into a single call for splitting (and optionally subsampling) data in a
#     oneliner.
#
#     Read more in the :ref:`User Guide <cross_validation>`.
#
#     Parameters
#     ----------
#     *arrays : sequence of indexables with same length / shape[0]
#         Allowed inputs are lists, numpy arrays, scipy-sparse
#         matrices or pandas dataframes.
#
#     test_size : float or int, default=None
#         If float, should be between 0.0 and 1.0 and represent the proportion
#         of the dataset to include in the test split. If int, represents the
# ...

# %%
len(X_train)
# Out:
# 134

# %%
len(X_test)
# Out:
# 66

# %%
X_train.shape
# Out:
# (134, 4)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_pred = model.predict(X_test)
test_pred
# Out:
# array([15.80815781, 19.59478441, 11.65318196, 16.90616123,  9.29324576,
#         6.9576299 , 20.42896073, 17.38903208,  9.71239699, 19.02565524,
#        12.19530761, 13.90394338, 13.56268927, 21.28245943, 18.16280173,
#         9.8029787 , 15.86148562,  7.98422928,  7.35967591, 20.53359563,
#         7.56171668, 17.98628427, 24.33018531, 22.83159769,  8.15767462,
#        12.85395477, 21.67491664,  7.94800332, 12.21190438, 12.65690113,
#        10.93612933, 19.06485468, 10.1732291 ,  6.92187944, 17.4389691 ,
#         8.03313785,  9.19227486,  8.03928278, 10.29570519, 10.45969989,
#        13.07752697,  9.54788603, 10.06209218,  7.92127873, 11.60672343,
#        10.34896889,  9.049393  , 16.39838593, 13.52531132, 20.95478715,
#        12.71188323, 14.18676282, 17.60078023, 10.98318481, 12.91935341,
#         5.37758202, 23.46028051, 12.2863173 , 19.03424647, 15.34584786,
#        15.20639729, 23.63877152,  6.7295472 , 19.97196922, 13.89679894,
#        21.08678567])

# %%
y_test
# Out:
# 37     14.7
# 109    19.8
# 31     11.9
# 89     16.7
# 66      9.5
#        ...
# 183    26.2
# 127     8.8
# 53     21.2
# 100    11.7
# 93     22.2
# Name: Sales, Length: 66, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
sns.histplot(data = df , x='Sales', bins=20)    #distribustion of sales
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %%
mae=mean_absolute_error(y_test, test_pred)
mae
# Out:
# 1.283878104660245

# %%
mse=mean_squared_error(y_test, test_pred)
mse
# Out:
# 2.4752617168438418

# %%
np.sqrt(mse)
# Out:
# 1.5732964491296106

# %%
r2_score(y_test, test_pred)
# Out:
# 0.9189766788589313

# %% [markdown]
# # Now checking whether LR is valid for data set

# %%
test_residual = y_test- test_pred
test_residual
# Out:
# 37    -1.108158
# 109    0.205216
# 31     0.246818
# 89    -0.206161
# 66     0.206754
#          ...
# 183    2.561228
# 127    2.070453
# 53     1.228031
# 100   -2.196799
# 93     1.113214
# Name: Sales, Length: 66, dtype: float64

# %%
sns.scatterplot(x=y_test, y=test_residual)
plt.axhline(y=0, color='red', ls='--')

# %%
sns.displot(test_residual, bins=25, kde=True)
plt.axvline(x=0, color='red', ls='--')

# %%
model.coef_
# Out:
# array([-0.00321936,  0.04476268,  0.18430525, -0.00190729])

# %%
y_hat=model.predict(X)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14,6))   # subplot 1x3 multiple graphs. axes defines where which graph goes.

axes[1].plot(df['TV'], df['Sales'], 'o',)
axes[1].plot(df['TV'], y_hat, 'o')
axes[1].set_ylabel('test_pred')
axes[1].set_title('TV Spend')

axes[0].plot(df['Radio'], df['Sales'], 'o',color ='red')
axes[0].plot(df['Radio'], y_hat, 'o')
axes[0].set_ylabel('test_pred')
axes[0].set_title('Radio Spend')

axes[2].plot(df['Newspaper'], df['Sales'], 'o')
axes[2].plot(df['Newspaper'], y_hat, 'o')
axes[2].set_ylabel('test_pred')
axes[2].set_title('newspaper Spend')
# Out:
# Text(0.5, 1.0, 'newspaper Spend')

# %% [markdown]
# ## Saving the model

# %%
from joblib import dump,load

# %%
import os

# %%
model_dir = 'models'
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'model.joblib')
dump(model, filepath)
# Out:
# ['models\\model.joblib']

# %% [markdown]
# ## Loading the model

# %%
load_model = load(r'D:\Python\ML Live\Modular1\ML_Live-\model\model.joblib')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17480\1119952969.py in <module>
# ----> 1 load_model = load(r'D:\Python\ML Live\Modular1\ML_Live-\model\model.joblib')
#
# c:\Users\sheip\anaconda3\envs\liveclass\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     577             obj = _unpickle(fobj)
#     578     else:
# --> 579         with open(filename, 'rb') as f:
#     580             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     581                 if isinstance(fobj, str):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Python\\ML Live\\Modular1\\ML_Live-\\model\\model.joblib'

# %%
load_model.coef_
# Out:
# array([-0.00321936,  0.04476268,  0.18430525, -0.00190729])

# %%
example = [[151,25,15,40]]

# %%
load_model.predict(example)
# Out:
# c:\Users\sheip\anaconda3\envs\liveclass\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([6.8904366])

# %% [markdown]
# ## Polynomial Regression

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales  total_spend
# 0             1  230.1   37.8       69.2   22.1        337.1
# 1             2   44.5   39.3       45.1   10.4        128.9
# 2             3   17.2   45.9       69.3    9.3        132.4
# 3             4  151.5   41.3       58.5   18.5        251.3
# 4             5  180.8   10.8       58.4   12.9        250.0
# ..          ...    ...    ...        ...    ...          ...
# 195         196   38.2    3.7       13.8    7.6         55.7
# 196         197   94.2    4.9        8.1    9.7        107.2
# 197         198  177.0    9.3        6.4   12.8        192.7
# 198         199  283.6   42.0       66.2   25.5        391.8
# 199         200  232.1    8.6        8.7   13.4        249.4
#
# [200 rows x 6 columns]

# %%
X1 = df.drop(['Sales', 'total_spend','Unnamed: 0'], axis =1,)
X1
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_conv = PolynomialFeatures(degree=2 , include_bias=False)

# %%
poly_conv.fit(X1)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = poly_conv.transform(X1)   # tranfer 3 feature to 9 feature to get 9 
                                           #parameters for degree 3.

# %%
poly_features
# Out:
# array([[ 230.1 ,   37.8 ,   69.2 , ..., 1428.84, 2615.76, 4788.64],
#        [  44.5 ,   39.3 ,   45.1 , ..., 1544.49, 1772.43, 2034.01],
#        [  17.2 ,   45.9 ,   69.3 , ..., 2106.81, 3180.87, 4802.49],
#        ...,
#        [ 177.  ,    9.3 ,    6.4 , ...,   86.49,   59.52,   40.96],
#        [ 283.6 ,   42.  ,   66.2 , ..., 1764.  , 2780.4 , 4382.44],
#        [ 232.1 ,    8.6 ,    8.7 , ...,   73.96,   74.82,   75.69]])

# %%
poly_features.shape
# Out:
# (200, 9)

# %%
X1.iloc[0]
# Out:
# TV           230.1
# Radio         37.8
# Newspaper     69.2
# Name: 0, dtype: float64

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
from sklearn.model_selection import train_test_split
X_trainP, X_testP, y_trainP, y_testP = train_test_split(poly_features, y, test_size=0.33, random_state=101)

# %%
X_trainP
# Out:
# array([[1.87800e+02, 2.11000e+01, 9.50000e+00, ..., 4.45210e+02,
#         2.00450e+02, 9.02500e+01],
#        [7.82000e+01, 4.68000e+01, 3.45000e+01, ..., 2.19024e+03,
#         1.61460e+03, 1.19025e+03],
#        [1.25700e+02, 3.69000e+01, 7.92000e+01, ..., 1.36161e+03,
#         2.92248e+03, 6.27264e+03],
#        ...,
#        [2.39800e+02, 4.10000e+00, 3.69000e+01, ..., 1.68100e+01,
#         1.51290e+02, 1.36161e+03],
#        [2.14700e+02, 2.40000e+01, 4.00000e+00, ..., 5.76000e+02,
#         9.60000e+01, 1.60000e+01],
#        [1.63300e+02, 3.16000e+01, 5.29000e+01, ..., 9.98560e+02,
#         1.67164e+03, 2.79841e+03]])

# %%
model1 = LinearRegression()

# %%
model1.fit(X_trainP, y_trainP)
# Out:
# LinearRegression()

# %%
test_pred_poly = model1.predict(X_testP)
test_pred_poly
# Out:
# array([13.97204613, 19.31163632, 12.34937446, 16.77918795,  7.86585082,
#         6.91555804, 20.11299294, 17.49707854, 10.56626076, 20.12510306,
#         9.45653268, 14.08673516, 12.06855682, 23.37172536, 19.67600099,
#         9.14838427, 12.13661295,  9.25938961,  8.42727726, 21.64817709,
#         7.0207988 , 19.36930318, 27.21526812, 24.54515558,  8.98640103,
#        11.86761484, 20.38278449,  9.22102483, 12.76121768,  8.64739673,
#         8.67463214, 20.20034879, 10.93174941,  6.85739529, 18.29226844,
#         9.5074497 , 10.35219229,  9.64459655,  7.4384789 , 11.03480643,
#        12.66080843, 10.69057937, 11.23958513,  7.4725002 , 11.38637684,
#        10.2667274 ,  6.12707279, 15.54892762, 13.43339421, 22.70762962,
#        10.41887348, 13.24665286, 14.2399427 , 11.85682389, 11.71631169,
#         5.5519889 , 25.01544605,  9.5463153 , 17.34861031, 15.7728373 ,
#        15.51033662, 25.57307088,  8.60367331, 21.60788857, 12.34127765,
#        22.21531611])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_testP, test_pred_poly)
MAE
# Out:
# 0.4842810535215552

# %%
MSE = mean_squared_error(y_testP, test_pred_poly)
MSE
# Out:
# 0.4202814842156936

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 0.6482912032533633

# %%
model1.coef_
# Out:
# array([ 5.25319441e-02,  1.42773271e-02,  1.47528851e-02, -1.12739168e-04,
#         1.13231490e-03, -5.42180033e-05,  6.26813126e-05,  8.93347558e-05,
#        -3.52004070e-05])

# %%
# Checking all model from degrees 1 to 9
train_rmse_errors = []
test_rmse_errors = []

for d in range(1,10):
    poly_converter = PolynomialFeatures(degree=d, include_bias=False)
    poly_features = poly_converter.fit_transform(X1)

    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.33, random_state=101)

    model = LinearRegression()
    model.fit(X_train, y_train)

    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test,test_pred))

    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [1.7376515982447711,
#  0.5947926597019145,
#  0.44059734232363623,
#  0.353291328203811,
#  0.24845372122354306,
#  0.18845501221719607,
#  4.8122654971456384,
#  0.15367149439061295,
#  0.15143250641278555]

# %%
test_rmse_errors   # overfitting is happening after the 4th degree
# Out:
# [1.5324409426512415,
#  0.6482912032533633,
#  0.5577254823367401,
#  0.5064297300349341,
#  2.3573691979064946,
#  11.255966950261778,
#  1206.02202904039,
#  3329.8532193354035,
#  174878.49346952146]

# %% [markdown]
# # Graph style

# %%
from matplotlib import style
style.use('fivethirtyeight')

# %%
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # graph for only 5 point

# %%
plt.plot(range(1,6),train_rmse_errors[:5], label = 'TRAIN_RMSE' )
plt.plot(range(1,6),test_rmse_errors[:5] ,label = 'TEST_RMSE' )
plt.xlabel('Model Complexity/ Degree of polynomial')
plt.ylabel('RMSE')
plt.legend()

# %% [markdown]
# ## graph for 9 points ( all point)

# %%
plt.plot(range(1,10),train_rmse_errors, label = 'TRAIN_RMSE' )
plt.plot(range(1,10),test_rmse_errors ,label = 'TEST_RMSE' )
plt.xlabel('Model Complexity/ Degree of polynomial')
plt.ylabel('RMSE')
plt.legend()

# %% [markdown]
# ### graph for only train_rmse_errors

# %%
plt.plot(range(1,10),train_rmse_errors, label = 'TRAIN_RMSE' )
plt.xlabel('Model Complexity/ Degree of polynomial')
plt.ylabel('RMSE')
plt.legend()

# %%
plt.plot(range(1,10),test_rmse_errors, label = 'TEST_RMSE' )
plt.xlabel('Model Complexity/ Degree of polynomial')
plt.ylabel('RMSE')
plt.legend()

# %%
from joblib import dump, load
import os

# %%
final_poly_converter = PolynomialFeatures(degree = 3 , include_bias=False)

# %%
final_model = LinearRegression()

# %%
full_converted_x = final_poly_converter.fit_transform(X1)
final_model.fit(full_converted_x,y)
# Out:
# LinearRegression()

# %%
model_dir='models'
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'poly.joblib')
dump(final_model, filepath)
# Out:
# ['models\\poly.joblib']

# %%
model_dir='models'
os.makedirs(model_dir, exist_ok=True)
filepath = os.path.join(model_dir, 'converter.joblib')
dump(final_poly_converter, filepath)
# Out:
# ['models\\converter.joblib']

# %%
Load_converter = load('D:\Python\ML Live\Modular1\ML_Live-\models\converter.joblib')

# %%
Load_model = load('D:\Python\ML Live\Modular1\ML_Live-\models\poly.joblib')

# %%
Load_model.coef_
# Out:
# array([ 1.23478783e-02,  8.52108235e-02,  6.16249400e-02, -1.39160339e-03,
#        -1.53807781e-04,  7.34520727e-05, -4.72564301e-04,  5.95307955e-05,
#        -4.33100083e-04,  1.37465385e-03, -1.49958677e-04, -7.94696425e-04,
#        -3.90255417e-04,  3.85331183e-04,  4.15670406e-07, -2.33402254e-07,
#         2.53868919e-06,  4.36914365e-07, -1.63354166e-08, -3.02802095e-07,
#        -6.70843453e-07, -1.44961785e-06,  1.81294009e-06, -7.40269231e-07,
#         7.54784046e-07, -1.23393269e-06,  7.12889066e-07,  2.02885080e-06,
#        -1.17977408e-06, -1.33046683e-07,  1.01396743e-05,  1.94579901e-06,
#         1.66506076e-06, -2.30813567e-06])

# %%
X1_arr= X1.to_numpy()
X1_arr
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...
